# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

file_path = '/content/drive/My Drive/Colab Notebooks/CFBQBPassing.xlsx'
df = pd.read_excel(file_path, header=0)
df = df.loc[:, ~df.columns.str.contains('Unnamed')]
df.head()
# Out:
# Mounted at /content/drive
#              PLAYER        TEAM  CFP RANK  SOS      CLASS  PASSING YARDS  \
# 0           CJ Carr  Notre Dame         9   29   Freshman           2487
# 1      Julian Sayin  Ohio State         1  5 0   Freshman           2675
# 2  Fernando Mendoza     Indiana         2   38     Junior           2641
# 3       Marcel Reed   Texas A&M         3   18  Sophomore           2632
# 4  Gunner Stockton      Georgia         4   12     Junior           2269
#
#    PASSING TDS  RUSHING TDS  INTS  COMPLETION %  PASS ATT  Yards Per Catch  \
# 0           21            3     6          67.3       257             14.4
# 1           25            0     4          80.1       282             11.9
# 2           30            5     5          73.0       278             13.0
# 3           22            6     8          61.5       291             14.7
# 4           19            8     3          70.7       287             11.2
#
#    TEAMS RUN%
# 0       57.46
# 1       53.54
# 2       59.92
# 3       56.21
# 4       57.66

# %% [markdown]
# Problem Statement:
#
# To evaluate whether CJ Carr ranks among the top quarterbacks in the league during his true freshman season by using statistical performance metrics.

# %% [markdown]
# We will first look at all the teams in the running for the College Football Playoffs and their respected strength of schedule (SOS)

# %%
ranked = (
    df[["TEAM", "CFP RANK", "SOS"]]
        .drop_duplicates()
        .sort_values(["SOS", "CFP RANK"])
        .reset_index(drop=True)
)

for _, row in ranked.iterrows():
    print(f"{row['TEAM']} - SOS: {row['SOS']} - CFP Rank: {row['CFP RANK']}")
# Out:
# Alabama - SOS: 4 - CFP Rank: 10
# Oklahoma - SOS: 10 - CFP Rank: 8
# Georgia - SOS: 12 - CFP Rank: 4
# Texas A&M - SOS: 18 - CFP Rank: 3
# Vanderbilt - SOS: 21 - CFP Rank: 14
# BYU - SOS: 27 - CFP Rank: 11
# Notre Dame - SOS: 29 - CFP Rank: 9
# Oregon - SOS: 31 - CFP Rank: 7
# Ole Miss - SOS: 32 - CFP Rank: 6
# USC - SOS: 36 - CFP Rank: 15
# Indiana - SOS: 38 - CFP Rank: 2
# Miami - SOS: 43 - CFP Rank: 13
# Utah - SOS: 46 - CFP Rank: 12
# Texas Tech - SOS: 52 - CFP Rank: 5
#  Georgia Tech - SOS: 88 - CFP Rank: 16
# Ohio State - SOS: 5 0 - CFP Rank: 1

# %% [markdown]
# Strength of schedule is a metric measuring how tough a team's opponents are, reflecting the difficulty of their overall schedule based on opponent quality (win percentages, ratings) and home/away games, crucial for comparing teams with different paths to the CFP.

# %% [markdown]
# We will now look at the first statistic, we will look at the correlation between passing attempts and passing yards!

# %%
import matplotlib.patches as mpatches
plt.figure(figsize=(12,8))
class_colors = {
    "Freshman": "purple",
    "Sophomore": "red",
    "Junior": "yellow",
    "Senior": "black"
}
for _, row in df.iterrows():
    name = row["PLAYER"]
    team = row["TEAM"]
    x = row["PASS ATT"]
    y = row["PASSING YARDS"]

    cls = row["CLASS"]
    color = class_colors.get(cls, "black")
    plt.scatter(x, y, color=color, s=80)
    plt.text(x, y, f"{name} ({team})", fontsize=8)

plt.xlabel("Passing Attempts")
plt.ylabel("Passing Yards")
plt.title("Passing Attempts vs Passing Yards by Player Class")

legend_handles = [
    mpatches.Patch(color="purple", label="Freshman"),
    mpatches.Patch(color="red", label="Sophomore"),
    mpatches.Patch(color="yellow", label="Junior"),
    mpatches.Patch(color="black", label="Senior")
]
plt.legend(handles=legend_handles)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Passing attempts and passing yards are directly correlated together, the more you attempt the pass the more likely you are to have more passing yards. However, there are some outliers like CJ Carr who has just as many passing yards on a lot less attempts.

# %% [markdown]
# We will now look at another stastic, we will look at the correlation between yards per completion to passing yards.

# %%
df["COMPLETIONS"] = (df["COMPLETION %"] / 100) * df["PASS ATT"]

plt.figure(figsize=(10,7))
plt.scatter(df["Yards Per Catch"], df["COMPLETIONS"], color="black")

for _, row in df.iterrows():
    name = row["PLAYER"]
    x = row["Yards Per Catch"]
    y = row["COMPLETIONS"]

    if name == "CJ Carr":
        plt.scatter(x, y, color="green", s=120)
        plt.text(x, y, f" ({name})", fontsize=10, color="green")
    else:
        plt.text(x, y, f" {name}", fontsize=8)

plt.xlabel("Yards Per Catch")
plt.ylabel("Completions")
plt.title("Yards Per Catch vs Completions")

plt.show()

# %% [markdown]
# Yards Per Catch vs. completions are directly correlated to each other as well as the previous graph. The more yards per catch per completion, the more passing yards a QB would have.

# %% [markdown]
# Finally, we will look at how often each team runs the football and the total amount of passing yards for each QB.

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["TEAMS RUN%"], df["PASSING YARDS"], color="skyblue")

for i, row in df.iterrows():
    plt.text(row["TEAMS RUN%"] + 0.2, row["PASSING YARDS"], row["TEAM"], fontsize=8)

plt.xlabel("Run %")
plt.ylabel("Passing Yards")
plt.title("Team Run % vs Passing Yards")
plt.grid(True)
plt.show()

# %% [markdown]
# How often a team runs the ball is direclty correlated to passing yards, as if a team runs the ball more they are more likely to have less passing yards and in turn more rushing yards.

# %% [markdown]
# To find a more equal way to compare the stats, I decided to standardize to 300 passing attempts and look at passing yards.

# %%
STANDARD_ATT = 300
df["PASSING_YARDS_NORM"] = df["PASSING YARDS"] / df["PASS ATT"] * STANDARD_ATT
df["PLAYER_TEAM"] = df["PLAYER"] + " (" + df["TEAM"] + ")"

plt.figure(figsize=(15,6))
plt.scatter(df["PLAYER_TEAM"], df["PASSING_YARDS_NORM"], color="blue", label="Blue - Standardized for 300 attempts")
plt.scatter(df["PLAYER_TEAM"], df["PASSING YARDS"], color="red", label="Red - Actual Passing Yards")
plt.xlabel("Quarterback (School)")
plt.ylabel("Passing Yards")
plt.title("Actual vs Standardized Passing Yards per QB")
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# This was done by taking each QBs passing yards divided by passing attempts and multiploed by 300. A scatterplot was then made to compare the original and standarized stats.

# %% [markdown]
# I decided to do the same process, but instead of passing yards I standarized passing touchdowns for each QB.

# %%
STANDARD_ATT = 300
df["PASS_TDS_300_ATT"] = df["PASSING TDS"] / df["PASS ATT"] * STANDARD_ATT
df["PLAYER_TEAM"] = df["PLAYER"] + " (" + df["TEAM"] + ")"

plt.figure(figsize=(15,6))
plt.scatter(df["PLAYER_TEAM"], df["PASS_TDS_300_ATT"], color="blue", label="Blue - Standardized for 300 attempts")
plt.scatter(df["PLAYER_TEAM"], df["PASSING TDS"], color="red", label="Red - Actual Passing TDs")
plt.xlabel("Quarterback (School)")
plt.ylabel("Passing TDs")
plt.title("Actual vs Standardized Passing TDs per QB")
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The code calculates a custom quarterback efficiency index (QBEI) for each player by combining per-attempt passing metrics, standardizes them using Z-scores, and then evaluates how CJ Carrs performance compares to other quarterbacks using a Z-score and one-tailed p-value to assess statistical significance. Essentially, it measures how exceptional CJ Carrs efficiency is relative to his peers

# %% [markdown]
# A QB Efficieny Index was created with these parameters. Yards Per Attempt (50%), TD/INT Ratio (30%), Completions (20%). Each metric into a z-score: how many standard deviations a player is above or below the mean.
#
# Why? Because YPA, TD-minus-INT, and completion % are on different scales. Z-scores make them comparable.

# %%
df["YPA"] = df["PASSING YARDS"] / df["PASS ATT"]
df["TD_MINUS_INT_PER_ATT"] = (df["PASSING TDS"] - df["INTS"]) / df["PASS ATT"]
df["COMP"] = df["COMPLETION %"]

metrics = ["YPA", "TD_MINUS_INT_PER_ATT", "COMP"]
for m in metrics:
    df[m + "_Z"] = (df[m] - df[m].mean()) / df[m].std(ddof=1)

# Weighted QBEI
df["QBEI"] = (
    0.50 * df["YPA_Z"] +
    0.30 * df["TD_MINUS_INT_PER_ATT_Z"] +
    0.20 * df["COMP_Z"]
)

cj = df[df["PLAYER"] == "CJ Carr"]["QBEI"].iloc[0]
others = df[df["PLAYER"] != "CJ Carr"]["QBEI"]
mean_o = others.mean()
std_o = others.std(ddof=1)

z = (cj - mean_o) / std_o
p = 1 - norm.cdf(z)

print("CJ Carr QBEI:", cj)
print("Z-score:", z)
print("One-tailed p-value:", p)
# Out:
# CJ Carr QBEI: 0.6989511565901857
# Z-score: 0.9107864530861067
# One-tailed p-value: 0.181203950828418

# %% [markdown]
# A 5 KFold Cross Validation was run to compare CJ Carrs QBEI to other QBs

# %%
from sklearn.model_selection import KFold
K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42)

rows = []

for fold, (_, test_idx) in enumerate(kf.split(others), 1):
    sample = others.iloc[test_idx]
    m = sample.mean()
    s = sample.std(ddof=1)

    z_fold = (cj - m) / s
    p_fold = 1 - norm.cdf(z_fold)

    rows.append([fold, m, s, z_fold, p_fold])

cv_matrix = pd.DataFrame(rows, columns=["Fold", "Mean_QBEI", "Std_QBEI", "Z_Score", "P_Value"])

print("\nK-Fold Cross-Validation Matrix:\n")
print(cv_matrix)
# Out:
# K-Fold Cross-Validation Matrix:
#
#    Fold  Mean_QBEI  Std_QBEI   Z_Score   P_Value
# 0     1   0.114102  1.129548  0.517772  0.302309
# 1     2  -0.015530  0.284435  2.511929  0.006004
# 2     3   0.431466  0.754300  0.354614  0.361439
# 3     4  -0.923055  1.013435  1.600504  0.054743
# 4     5   0.160033  0.371959  1.448865  0.073688

# %% [markdown]
# Fold 1: Carr is slightly above average vs this sample. Not significant.
#
# Fold 2: Carr is MUCH better than this fold. Statistically significant.
#
# Fold 3: Carr about average.
#
# Fold 4: Car is borderline significant (just above 0.05).
#
# Fold 5: Carr is once again slightly above average, not significant.

# %% [markdown]
# Null Hypothesis: CJ Carr is not better than the average QB in this study
#
# Alternate Hypothesis: CJ Carr is better than the average QB in this study
#
# Results: CJ Carrs QBEI is above average, however is not statistical significant :(

# %% [markdown]
# A one feature logistic regression model was run using each teams passing yards to determine if the team was a pass heavy or run heavy team. This correlates to the study as if a team was run heavy, the QB would have less viable stats for comparision.

# %%
df['OFFENSE_TYPE'] = df['TEAMS RUN%'].apply(lambda x: 'Run-Heavy' if x > 50 else 'Pass-Heavy')
X = df[['PASSING YARDS']]
y = df['OFFENSE_TYPE']
model = LogisticRegression()
model.fit(X, y)
df['PREDICTED_OFFENSE'] = model.predict(X)
df_ranked = df.sort_values(by='TEAMS RUN%', ascending=False)
final_output = df_ranked[['TEAM', 'PASSING YARDS', 'TEAMS RUN%', 'OFFENSE_TYPE', 'PREDICTED_OFFENSE']]
def highlight_correct(row):
    color = 'background-color: '
    return [
        color + 'darkgreen' if row['OFFENSE_TYPE'] == row['PREDICTED_OFFENSE'] else color + 'red'
        for _ in row
    ]
styled_output = final_output.style.apply(highlight_correct, axis=1)
accuracy_full = (df['OFFENSE_TYPE'] == df['PREDICTED_OFFENSE']).mean()
print(f"Model Accuracy: {accuracy_full:.4f} ({accuracy_full*100:.2f}%)")
styled_output
# Out:
# Model Accuracy: 0.9375 (93.75%)
# <style type="text/css">
# #T_b3f5c_row0_col0, #T_b3f5c_row0_col1, #T_b3f5c_row0_col2, #T_b3f5c_row0_col3, #T_b3f5c_row0_col4, #T_b3f5c_row1_col0, #T_b3f5c_row1_col1, #T_b3f5c_row1_col2, #T_b3f5c_row1_col3, #T_b3f5c_row1_col4, #T_b3f5c_row2_col0, #T_b3f5c_row2_col1, #T_b3f5c_row2_col2, #T_b3f5c_row2_col3, #T_b3f5c_row2_col4, #T_b3f5c_row3_col0, #T_b3f5c_row3_col1, #T_b3f5c_row3_col2, #T_b3f5c_row3_col3, #T_b3f5c_row3_col4, #T_b3f5c_row4_col0, #T_b3f5c_row4_col1, #T_b3f5c_row4_col2, #T_b3f5c_row4_col3, #T_b3f5c_row4_col4, #T_b3f5c_row5_col0, #T_b3f5c_row5_col1, #T_b3f5c_row5_col2, #T_b3f5c_row5_col3, #T_b3f5c_row5_col4, #T_b3f5c_row6_col0, #T_b3f5c_row6_col1, #T_b3f5c_row6_col2, #T_b3f5c_row6_col3, #T_b3f5c_row6_col4, #T_b3f5c_row7_col0, #T_b3f5c_row7_col1, #T_b3f5c_row7_col2, #T_b3f5c_row7_col3, #T_b3f5c_row7_col4, #T_b3f5c_row8_col0, #T_b3f5c_row8_col1, #T_b3f5c_row8_col2, #T_b3f5c_row8_col3, #T_b3f5c_row8_col4, #T_b3f5c_row9_col0, #T_b3f5c_row9_col1, #T_b3f5c_row9_col2, #T_b3f5c_row9_col3, #T_b3f5c_row9_col4, #T_b3f5c_row10_col0, #T_b3f5c_row10_col1, #T_b3f5c_row10_col2, #T_b3f5c_row10_col3, #T_b3f5c_row10_col4, #T_b3f5c_row11_col0, #T_b3f5c_row11_col1, #T_b3f5c_row11_col2, #T_b3f5c_row11_col3, #T_b3f5c_row11_col4, #T_b3f5c_row12_col0, #T_b3f5c_row12_col1, #T_b3f5c_row12_col2, #T_b3f5c_row12_col3, #T_b3f5c_row12_col4, #T_b3f5c_row13_col0, #T_b3f5c_row13_col1, #T_b3f5c_row13_col2, #T_b3f5c_row13_col3, #T_b3f5c_row13_col4, #T_b3f5c_row14_col0, #T_b3f5c_row14_col1, #T_b3f5c_row14_col2, #T_b3f5c_row14_col3, #T_b3f5c_row14_col4 {
#   background-color: darkgreen;
# }
# #T_b3f5c_row15_col0, #T_b3f5c_row15_col1, #T_b3f5c_row15_col2, #T_b3f5c_row15_col3, #T_b3f5c_row15_col4 {
#   background-color: red;
# }
# </style>
# <table id="T_b3f5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3f5c_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_b3f5c_level0_col1" class="col_heading level0 col1" >PASSING YARDS</th>
#       <th id="T_b3f5c_level0_col2" class="col_heading level0 col2" >TEAMS RUN%</th>
#       <th id="T_b3f5c_level0_col3" class="col_heading level0 col3" >OFFENSE_TYPE</th>
#       <th id="T_b3f5c_level0_col4" class="col_heading level0 col4" >PREDICTED_OFFENSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3f5c_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_b3f5c_row0_col0" class="data row0 col0" >Utah</td>
#       <td id="T_b3f5c_row0_col1" class="data row0 col1" >1668</td>
#       <td id="T_b3f5c_row0_col2" class="data row0 col2" >61.340000</td>
#       <td id="T_b3f5c_row0_col3" class="data row0 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row0_col4" class="data row0 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b3f5c_row1_col0" class="data row1 col0" >Indiana</td>
#       <td id="T_b3f5c_row1_col1" class="data row1 col1" >2641</td>
#       <td id="T_b3f5c_row1_col2" class="data row1 col2" >59.920000</td>
#       <td id="T_b3f5c_row1_col3" class="data row1 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row1_col4" class="data row1 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_b3f5c_row2_col0" class="data row2 col0" >BYU</td>
#       <td id="T_b3f5c_row2_col1" class="data row2 col1" >2177</td>
#       <td id="T_b3f5c_row2_col2" class="data row2 col2" >57.690000</td>
#       <td id="T_b3f5c_row2_col3" class="data row2 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row2_col4" class="data row2 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b3f5c_row3_col0" class="data row3 col0" >Georgia</td>
#       <td id="T_b3f5c_row3_col1" class="data row3 col1" >2269</td>
#       <td id="T_b3f5c_row3_col2" class="data row3 col2" >57.660000</td>
#       <td id="T_b3f5c_row3_col3" class="data row3 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row3_col4" class="data row3 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_b3f5c_row4_col0" class="data row4 col0" >Notre Dame</td>
#       <td id="T_b3f5c_row4_col1" class="data row4 col1" >2487</td>
#       <td id="T_b3f5c_row4_col2" class="data row4 col2" >57.460000</td>
#       <td id="T_b3f5c_row4_col3" class="data row4 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row4_col4" class="data row4 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_b3f5c_row5_col0" class="data row5 col0" > Georgia Tech</td>
#       <td id="T_b3f5c_row5_col1" class="data row5 col1" >2259</td>
#       <td id="T_b3f5c_row5_col2" class="data row5 col2" >57.240000</td>
#       <td id="T_b3f5c_row5_col3" class="data row5 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row5_col4" class="data row5 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b3f5c_row6_col0" class="data row6 col0" >Oregon</td>
#       <td id="T_b3f5c_row6_col1" class="data row6 col1" >2190</td>
#       <td id="T_b3f5c_row6_col2" class="data row6 col2" >57.180000</td>
#       <td id="T_b3f5c_row6_col3" class="data row6 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row6_col4" class="data row6 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_b3f5c_row7_col0" class="data row7 col0" >Texas A&M</td>
#       <td id="T_b3f5c_row7_col1" class="data row7 col1" >2632</td>
#       <td id="T_b3f5c_row7_col2" class="data row7 col2" >56.210000</td>
#       <td id="T_b3f5c_row7_col3" class="data row7 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row7_col4" class="data row7 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_b3f5c_row8_col0" class="data row8 col0" >Ole Miss</td>
#       <td id="T_b3f5c_row8_col1" class="data row8 col1" >2656</td>
#       <td id="T_b3f5c_row8_col2" class="data row8 col2" >55.030000</td>
#       <td id="T_b3f5c_row8_col3" class="data row8 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row8_col4" class="data row8 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_b3f5c_row9_col0" class="data row9 col0" >Ohio State</td>
#       <td id="T_b3f5c_row9_col1" class="data row9 col1" >2675</td>
#       <td id="T_b3f5c_row9_col2" class="data row9 col2" >53.540000</td>
#       <td id="T_b3f5c_row9_col3" class="data row9 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row9_col4" class="data row9 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_b3f5c_row10_col0" class="data row10 col0" >Miami</td>
#       <td id="T_b3f5c_row10_col1" class="data row10 col1" >2485</td>
#       <td id="T_b3f5c_row10_col2" class="data row10 col2" >53.540000</td>
#       <td id="T_b3f5c_row10_col3" class="data row10 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row10_col4" class="data row10 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row11" class="row_heading level0 row11" >5</th>
#       <td id="T_b3f5c_row11_col0" class="data row11 col0" >Texas Tech</td>
#       <td id="T_b3f5c_row11_col1" class="data row11 col1" >2118</td>
#       <td id="T_b3f5c_row11_col2" class="data row11 col2" >52.980000</td>
#       <td id="T_b3f5c_row11_col3" class="data row11 col3" >Run-Heavy</td>
#       <td id="T_b3f5c_row11_col4" class="data row11 col4" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_b3f5c_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_b3f5c_row12_col0" class="data row12 col0" >Vanderbilt</td>
#       <td id="T_b3f5c_row12_col1" class="data row12 col1" >2440</td>
#       <td id="T_b3f5c_row12_col2" class="data row12 col2" >52.630000</td>
#       <td i

# %% [markdown]
# This code labels each team as Run-Heavy or Pass-Heavy based on whether their run percentage exceeds 50%, then trains a logistic regression model using passing yards to predict that offensive style. It compares the models predictions to the actual labels, highlights correct vs. incorrect predictions in the final table, and prints the models overall accuracy. The model accuracy was 93.75%

# %% [markdown]
# Now, a two feature logistic regression model was run using each teams passing yards and passing attempts to determine if the team was a pass heavy or run heavy team. This correlates to the study as if a team was run heavy, the QB would have less viable stats for comparision.

# %%
df['OFFENSE_TYPE'] = df['TEAMS RUN%'].apply(lambda x: 'Run-Heavy' if x > 50 else 'Pass-Heavy')
X = df[['PASSING YARDS', 'PASS ATT']]
y = df['OFFENSE_TYPE']

model = LogisticRegression()
model.fit(X, y)

df['PREDICTED_OFFENSE'] = model.predict(X)
df_ranked = df.sort_values(by='TEAMS RUN%', ascending=False)
final_output = df_ranked[['TEAM', 'PASSING YARDS', 'PASS ATT', 'TEAMS RUN%', 'OFFENSE_TYPE', 'PREDICTED_OFFENSE']]

def highlight_correct(row):
    color = 'background-color: '
    return [
        color + 'darkgreen' if row['OFFENSE_TYPE'] == row['PREDICTED_OFFENSE'] else color + 'salmon'
        for _ in row
    ]
styled_output = final_output.style.apply(highlight_correct, axis=1)

accuracy_full = (df['OFFENSE_TYPE'] == df['PREDICTED_OFFENSE']).mean()
print(f"Model Accuracy (full dataset): {accuracy_full:.4f} ({accuracy_full*100:.2f}%)")

styled_output
# Out:
# Model Accuracy (full dataset): 1.0000 (100.00%)
# <style type="text/css">
# #T_2fb2f_row0_col0, #T_2fb2f_row0_col1, #T_2fb2f_row0_col2, #T_2fb2f_row0_col3, #T_2fb2f_row0_col4, #T_2fb2f_row0_col5, #T_2fb2f_row1_col0, #T_2fb2f_row1_col1, #T_2fb2f_row1_col2, #T_2fb2f_row1_col3, #T_2fb2f_row1_col4, #T_2fb2f_row1_col5, #T_2fb2f_row2_col0, #T_2fb2f_row2_col1, #T_2fb2f_row2_col2, #T_2fb2f_row2_col3, #T_2fb2f_row2_col4, #T_2fb2f_row2_col5, #T_2fb2f_row3_col0, #T_2fb2f_row3_col1, #T_2fb2f_row3_col2, #T_2fb2f_row3_col3, #T_2fb2f_row3_col4, #T_2fb2f_row3_col5, #T_2fb2f_row4_col0, #T_2fb2f_row4_col1, #T_2fb2f_row4_col2, #T_2fb2f_row4_col3, #T_2fb2f_row4_col4, #T_2fb2f_row4_col5, #T_2fb2f_row5_col0, #T_2fb2f_row5_col1, #T_2fb2f_row5_col2, #T_2fb2f_row5_col3, #T_2fb2f_row5_col4, #T_2fb2f_row5_col5, #T_2fb2f_row6_col0, #T_2fb2f_row6_col1, #T_2fb2f_row6_col2, #T_2fb2f_row6_col3, #T_2fb2f_row6_col4, #T_2fb2f_row6_col5, #T_2fb2f_row7_col0, #T_2fb2f_row7_col1, #T_2fb2f_row7_col2, #T_2fb2f_row7_col3, #T_2fb2f_row7_col4, #T_2fb2f_row7_col5, #T_2fb2f_row8_col0, #T_2fb2f_row8_col1, #T_2fb2f_row8_col2, #T_2fb2f_row8_col3, #T_2fb2f_row8_col4, #T_2fb2f_row8_col5, #T_2fb2f_row9_col0, #T_2fb2f_row9_col1, #T_2fb2f_row9_col2, #T_2fb2f_row9_col3, #T_2fb2f_row9_col4, #T_2fb2f_row9_col5, #T_2fb2f_row10_col0, #T_2fb2f_row10_col1, #T_2fb2f_row10_col2, #T_2fb2f_row10_col3, #T_2fb2f_row10_col4, #T_2fb2f_row10_col5, #T_2fb2f_row11_col0, #T_2fb2f_row11_col1, #T_2fb2f_row11_col2, #T_2fb2f_row11_col3, #T_2fb2f_row11_col4, #T_2fb2f_row11_col5, #T_2fb2f_row12_col0, #T_2fb2f_row12_col1, #T_2fb2f_row12_col2, #T_2fb2f_row12_col3, #T_2fb2f_row12_col4, #T_2fb2f_row12_col5, #T_2fb2f_row13_col0, #T_2fb2f_row13_col1, #T_2fb2f_row13_col2, #T_2fb2f_row13_col3, #T_2fb2f_row13_col4, #T_2fb2f_row13_col5, #T_2fb2f_row14_col0, #T_2fb2f_row14_col1, #T_2fb2f_row14_col2, #T_2fb2f_row14_col3, #T_2fb2f_row14_col4, #T_2fb2f_row14_col5, #T_2fb2f_row15_col0, #T_2fb2f_row15_col1, #T_2fb2f_row15_col2, #T_2fb2f_row15_col3, #T_2fb2f_row15_col4, #T_2fb2f_row15_col5 {
#   background-color: darkgreen;
# }
# </style>
# <table id="T_2fb2f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fb2f_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_2fb2f_level0_col1" class="col_heading level0 col1" >PASSING YARDS</th>
#       <th id="T_2fb2f_level0_col2" class="col_heading level0 col2" >PASS ATT</th>
#       <th id="T_2fb2f_level0_col3" class="col_heading level0 col3" >TEAMS RUN%</th>
#       <th id="T_2fb2f_level0_col4" class="col_heading level0 col4" >OFFENSE_TYPE</th>
#       <th id="T_2fb2f_level0_col5" class="col_heading level0 col5" >PREDICTED_OFFENSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fb2f_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_2fb2f_row0_col0" class="data row0 col0" >Utah</td>
#       <td id="T_2fb2f_row0_col1" class="data row0 col1" >1668</td>
#       <td id="T_2fb2f_row0_col2" class="data row0 col2" >245</td>
#       <td id="T_2fb2f_row0_col3" class="data row0 col3" >61.340000</td>
#       <td id="T_2fb2f_row0_col4" class="data row0 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row0_col5" class="data row0 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2fb2f_row1_col0" class="data row1 col0" >Indiana</td>
#       <td id="T_2fb2f_row1_col1" class="data row1 col1" >2641</td>
#       <td id="T_2fb2f_row1_col2" class="data row1 col2" >278</td>
#       <td id="T_2fb2f_row1_col3" class="data row1 col3" >59.920000</td>
#       <td id="T_2fb2f_row1_col4" class="data row1 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row1_col5" class="data row1 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_2fb2f_row2_col0" class="data row2 col0" >BYU</td>
#       <td id="T_2fb2f_row2_col1" class="data row2 col1" >2177</td>
#       <td id="T_2fb2f_row2_col2" class="data row2 col2" >272</td>
#       <td id="T_2fb2f_row2_col3" class="data row2 col3" >57.690000</td>
#       <td id="T_2fb2f_row2_col4" class="data row2 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row2_col5" class="data row2 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2fb2f_row3_col0" class="data row3 col0" >Georgia</td>
#       <td id="T_2fb2f_row3_col1" class="data row3 col1" >2269</td>
#       <td id="T_2fb2f_row3_col2" class="data row3 col2" >287</td>
#       <td id="T_2fb2f_row3_col3" class="data row3 col3" >57.660000</td>
#       <td id="T_2fb2f_row3_col4" class="data row3 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row3_col5" class="data row3 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_2fb2f_row4_col0" class="data row4 col0" >Notre Dame</td>
#       <td id="T_2fb2f_row4_col1" class="data row4 col1" >2487</td>
#       <td id="T_2fb2f_row4_col2" class="data row4 col2" >257</td>
#       <td id="T_2fb2f_row4_col3" class="data row4 col3" >57.460000</td>
#       <td id="T_2fb2f_row4_col4" class="data row4 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row4_col5" class="data row4 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_2fb2f_row5_col0" class="data row5 col0" > Georgia Tech</td>
#       <td id="T_2fb2f_row5_col1" class="data row5 col1" >2259</td>
#       <td id="T_2fb2f_row5_col2" class="data row5 col2" >253</td>
#       <td id="T_2fb2f_row5_col3" class="data row5 col3" >57.240000</td>
#       <td id="T_2fb2f_row5_col4" class="data row5 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row5_col5" class="data row5 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2fb2f_row6_col0" class="data row6 col0" >Oregon</td>
#       <td id="T_2fb2f_row6_col1" class="data row6 col1" >2190</td>
#       <td id="T_2fb2f_row6_col2" class="data row6 col2" >254</td>
#       <td id="T_2fb2f_row6_col3" class="data row6 col3" >57.180000</td>
#       <td id="T_2fb2f_row6_col4" class="data row6 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row6_col5" class="data row6 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_2fb2f_row7_col0" class="data row7 col0" >Texas A&M</td>
#       <td id="T_2fb2f_row7_col1" class="data row7 col1" >2632</td>
#       <td id="T_2fb2f_row7_col2" class="data row7 col2" >291</td>
#       <td id="T_2fb2f_row7_col3" class="data row7 col3" >56.210000</td>
#       <td id="T_2fb2f_row7_col4" class="data row7 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row7_col5" class="data row7 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_2fb2f_row8_col0" class="data row8 col0" >Ole Miss</td>
#       <td id="T_2fb2f_row8_col1" class="data row8 col1" >2656</td>
#       <td id="T_2fb2f_row8_col2" class="data row8 col2" >299</td>
#       <td id="T_2fb2f_row8_col3" class="data row8 col3" >55.030000</td>
#       <td id="T_2fb2f_row8_col4" class="data row8 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row8_col5" class="data row8 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_2fb2f_row9_col0" class="data row9 col0" >Ohio State</td>
#       <td id="T_2fb2f_row9_col1" class="data row9 col1" >2675</td>
#       <td id="T_2fb2f_row9_col2" class="data row9 col2" >282</td>
#       <td id="T_2fb2f_row9_col3" class="data row9 col3" >53.540000</td>
#       <td id="T_2fb2f_row9_col4" class="data row9 col4" >Run-Heavy</td>
#       <td id="T_2fb2f_row9_col5" class="data row9 col5" >Run-Heavy</td>
#     </tr>
#     <tr>
#       <th id="T_2fb2f_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_2fb2f_row10_col0" class="data row10 col0" >Miami</td>
#       <td id="T_2fb2f_row10_col1" class

# %% [markdown]
#  The model accuracy was now 100.0%. The addition of a second feature greatly improved the model

# %% [markdown]
# I would be comfortable with my project (slides & code) being shown to future students!

# %%
#LINK TO GITHUB
## https://github.com/TylerEvangelista/CSC-FINAL-PROJECT-SUBMISSION
